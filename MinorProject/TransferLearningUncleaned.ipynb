# %%
import os
import cv2
import math
import numpy as np
import pandas as pd

import scikitplot
import seaborn as sns
from matplotlib import pyplot

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

import tensorflow as tf
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten, Dense, GlobalAvgPool2D, GlobalMaxPool2D
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.utils import plot_model

from keras.utils import np_utils

# %%
INPUT_PATH = "C:\\Users\\varma\\Desktop\\Combine\\Combine"

# %%
total_images = 0
for dir_ in os.listdir(INPUT_PATH):
    count = 0
    
    for f in os.listdir(INPUT_PATH +"/"+ dir_ ):
        count += 1
        total_images += 1
    print(f"{dir_} has {count} number of images")
    
print(f"\ntotal images are {total_images}")
# Out:
# angry has 4953 number of images
# disgust has 547 number of images
# fear has 5121 number of images
# happy has 8989 number of images
# neutral has 6198 number of images
# sad has 6077 number of images
# surprise has 4002 number of images
#
# total images are 35887

# %%
TOP_EMOTIONS = ["happy", "neutral", "sad"]
total_images -= 14623
total_images
# Out:
# 21264

# %%
img_arr = np.empty(shape=(total_images,48,48,3))
img_label = np.empty(shape=(total_images))
label_to_text = {}

i = 0
e = 0
for dir_ in os.listdir(INPUT_PATH):
    if dir_ in TOP_EMOTIONS:
        label_to_text[e] = dir_
        for f in os.listdir(INPUT_PATH +"/"+ dir_ ):
            img_arr[i] = cv2.imread(INPUT_PATH +"/"+ dir_ +"/"+ f)
            img_label[i] = e
            i += 1
        print(f"loaded all {dir_} images to numpy arrays")
        e += 1

img_arr.shape, img_label
# Out:
# loaded all happy images to numpy arrays
# loaded all neutral images to numpy arrays
# loaded all sad images to numpy arrays
# ((21264, 48, 48, 3), array([0., 0., 0., ..., 2., 2., 2.]))

# %%
label_to_text
# Out:
# {0: 'happy', 1: 'neutral', 2: 'sad'}

# %%
fig = pyplot.figure(1, (8,8))

idx = 0
for k in label_to_text:
    sample_indices = np.random.choice(np.where(img_label==k)[0], size=4, replace=False)
    sample_images = img_arr[sample_indices]
    for img in sample_images:
        idx += 1
        ax = pyplot.subplot(4,4,idx)
        ax.imshow(img[:,:,0], cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(label_to_text[k])
        pyplot.tight_layout()

# %%
img_label = np_utils.to_categorical(img_label)
img_label.shape
# Out:
# (21264, 3)

# %%
img_arr = img_arr / 255.

# %%
X_train, X_test, y_train, y_test = train_test_split(img_arr, img_label,
                                                    shuffle=True, stratify=img_label,
                                                    train_size=0.9, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((19137, 48, 48, 3), (2127, 48, 48, 3), (19137, 3), (2127, 3))

# %%
del img_arr
del img_label

# %%
img_width = X_train.shape[1]
img_height = X_train.shape[2]
img_depth = X_train.shape[3]
num_classes = y_train.shape[1]

# %%
mobile_net = MobileNet(
    input_shape = (img_width, img_height, img_depth),
    include_top = False,
    weights = "imagenet",
    classes = num_classes
)

x = mobile_net.layers[-14].output
global_pool = GlobalMaxPool2D(name="global_pool")(x)
out = Dense(num_classes, activation="softmax", name="out_layer")(global_pool)

model = Model(inputs=mobile_net.input, outputs=out)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
plot_model(model, show_shapes=True, show_layer_names=True, expand_nested=True, dpi=50, to_file='mobilenet.png')
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
for layer in model.layers[:15]:
    layer.trainable = False

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.15,
    zoom_range=0.15,
    horizontal_flip=True,
    zca_whitening=False,
)
train_datagen.fit(X_train)

# %%
"""
I used two callbacks one is `early stopping` for avoiding overfitting training data
and other `ReduceLROnPlateau` for learning rate.
"""
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.00008,
    patience=11,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    min_delta=0.0001,
    factor=0.25,
    patience=4,
    min_lr=1e-7,
    verbose=1,
)

callbacks = [
    early_stopping,
    lr_scheduler,
]

# %%
batch_size = 35
epochs = 35

optims = [
    optimizers.Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07),
    optimizers.Adam(0.01),
]

model.compile(
        loss='categorical_crossentropy',
        optimizer=optims[1],
        metrics=['accuracy']
)


history = model.fit_generator(
    train_datagen.flow(X_train, y_train, batch_size=batch_size),
    validation_data=(X_test, y_test),
    steps_per_epoch=len(X_train) / batch_size,
    epochs=epochs,
    callbacks=callbacks,
#     use_multiprocessing=True
)
# Out:
# Epoch 1/35
# 547/546 [==============================] - 107s 196ms/step - loss: 1.0366 - accuracy: 0.5451 - val_loss: 0.9498 - val_accuracy: 0.6328
# Epoch 2/35
# 547/546 [==============================] - 107s 196ms/step - loss: 0.7474 - accuracy: 0.6609 - val_loss: 0.7166 - val_accuracy: 0.6831curacy
# Epoch 3/35
# 547/546 [==============================] - 106s 193ms/step - loss: 0.6908 - accuracy: 0.6917 - val_loss: 0.6761 - val_accuracy: 0.7029
# Epoch 4/35
# 547/546 [==============================] - 106s 194ms/step - loss: 0.6747 - accuracy: 0.7039 - val_loss: 0.6300 - val_accuracy: 0.7170
# Epoch 5/35
# 547/546 [==============================] - 105s 193ms/step - loss: 0.6436 - accuracy: 0.7173 - val_loss: 0.7611 - val_accuracy: 0.6432
# Epoch 6/35
# 547/546 [==============================] - 106s 194ms/step - loss: 0.6371 - accuracy: 0.7250 - val_loss: 0.6471 - val_accuracy: 0.7170
# Epoch 7/35
# 547/546 [==============================] - 85s 156ms/step - loss: 0.6319 - accuracy: 0.7299 - val_loss: 0.7467 - val_accuracy: 0.6888
# Epoch 8/35
# 547/546 [==============================] - ETA: 0s - loss: 0.6225 - accuracy: 0.7321
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 547/546 [==============================] - 86s 157ms/step - loss: 0.6225 - accuracy: 0.7321 - val_loss: 0.6924 - val_accuracy: 0.7076
# Epoch 9/35
# 547/546 [==============================] - 87s 159ms/step - loss: 0.5658 - accuracy: 0.7530 - val_loss: 0.5539 - val_accuracy: 0.7504
# Epoch 10/35
# 547/546 [==============================] - 87s 159ms/step - loss: 0.5568 - accuracy: 0.7605 - val_loss: 0.5716 - val_accuracy: 0.7409
# Epoch 11/35
# 547/546 [==============================] - 86s 158ms/step - loss: 0.5414 - accuracy: 0.7673 - val_loss: 0.5284 - val_accuracy: 0.7687
# Epoch 12/35
# 547/546 [==============================] - 85s 155ms/step - loss: 0.5339 - accuracy: 0.7722 - val_loss: 0.5150 - val_accuracy: 0.7757
# Epoch 13/35
# 547/546 [==============================] - 86s 156ms/step - loss: 0.5284 - accuracy: 0.7746 - val_loss: 0.5258 - val_accuracy: 0.7588
# Epoch 14/35
# 547/546 [==============================] - 85s 156ms/step - loss: 0.5292 - accuracy: 0.7751 - val_loss: 0.5383 - val_accuracy: 0.7616
# Epoch 15/35
# 547/546 [==============================] - 85s 156ms/step - loss: 0.5222 - accuracy: 0.7765 - val_loss: 0.5429 - val_accuracy: 0.7579
# Epoch 16/35
# 547/546 [==============================] - ETA: 0s - loss: 0.5184 - accuracy: 0.7803
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 547/546 [==============================] - 85s 156ms/step - loss: 0.5184 - accuracy: 0.7803 - val_loss: 0.5484 - val_accuracy: 0.7739
# Epoch 17/35
# 547/546 [==============================] - 94s 171ms/step - loss: 0.4929 - accuracy: 0.7894 - val_loss: 0.4966 - val_accuracy: 0.7828
# Epoch 18/35
# 547/546 [==============================] - 106s 194ms/step - loss: 0.4873 - accuracy: 0.7937 - val_loss: 0.4967 - val_accuracy: 0.7828
# Epoch 19/35
# 547/546 [==============================] - 106s 194ms/step - loss: 0.4853 - accuracy: 0.7965 - val_loss: 0.4979 - val_accuracy: 0.7884
# Epoch 20/35
# 547/546 [==============================] - 106s 194ms/step - loss: 0.4808 - accuracy: 0.7954 - val_loss: 0.4861 - val_accuracy: 0.7851
# Epoch 21/35
# 547/546 [==============================] - 109s 199ms/step - loss: 0.4792 - accuracy: 0.7969 - val_loss: 0.4870 - val_accuracy: 0.7861
# Epoch 22/35
# 547/546 [==============================] - 106s 194ms/step - loss: 0.4722 - accuracy: 0.8005 - val_loss: 0.4904 - val_accuracy: 0.7861
# Epoch 23/35
# 547/546 [==============================] - ETA: 0s - loss: 0.4675 - accuracy: 0.8013 - ETA: 19s - loss: 0 - ETA: 14s - loss: 0.4679 - ETA: 2s - loss: 0.4
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# 547/546 [==============================] - 106s 194ms/step - loss: 0.4675 - accuracy: 0.8013 - val_loss: 0.4859 - val_accuracy: 0.7875
# Epoch 24/35
# 547/546 [==============================] - 108s 197ms/step - loss: 0.4683 - accuracy: 0.8026 - val_loss: 0.4789 - val_accuracy: 0.7950
# Epoch 25/35
# 547/546 [==============================] - 95s 174ms/step - loss: 0.4619 - accuracy: 0.8072 - val_loss: 0.4757 - val_accuracy: 0.7941
# Epoch 26/35
# 547/546 [==============================] - 86s 158ms/step - loss: 0.4613 - accuracy: 0.8057 - val_loss: 0.4781 - val_accuracy: 0.7922
# Epoch 27/35
# 547/546 [==============================] - 88s 162ms/step - loss: 0.4618 - accuracy: 0.8048 - val_loss: 0.4761 - val_accuracy: 0.7927
# Epoch 28/35
# 547/546 [==============================] - ETA: 0s - loss: 0.4592 - accuracy: 0.8055
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# 547/546 [==============================] - 88s 160ms/step - loss: 0.4592 - accuracy: 0.8055 - val_loss: 0.4799 - val_accuracy: 0.7936
# Epoch 29/35
# 547/546 [==============================] - 86s 158ms/step - loss: 0.4626 - accuracy: 0.8064 - val_loss: 0.4776 - val_accuracy: 0.7955
# Epoch 30/35
# 547/546 [==============================] - 116s 213ms/step - loss: 0.4602 - accuracy: 0.8078 - val_loss: 0.4770 - val_accuracy: 0.7964
# Epoch 31/35
# 547/546 [==============================] - 114s 209ms/step - loss: 0.4587 - accuracy: 0.8069 - val_loss: 0.4777 - val_accuracy: 0.7964
# Epoch 32/35
# 547/546 [==============================] - 115s 210ms/step - loss: 0.4593 - accuracy: 0.8080 - val_loss: 0.4774 - val_accuracy: 0.7969
# Epoch 33/35
# 547/546 [==============================] - 115s 210ms/step - loss: 0.4602 - accuracy: 0.8084 - val_loss: 0.4782 - val_accuracy: 0.7936
# Epoch 34/35
# 547/546 [==============================] - 112s 204ms/step - loss: 0.4554 - accuracy: 0.8109 - val_loss: 0.4772 - val_accuracy: 0.7950
# Epoch 35/35
# 547/546 [==============================] - 107s 196ms/step - loss: 0.4576 - accuracy: 0.8053 - val_loss: 0.4779 - val_accuracy: 0.7978

# %%
model_yaml = model.to_json()
with open("model_mobelnet.yaml", "w") as yaml_file:
    yaml_file.write(model_yaml)
    
model.save("model_moblenet.h5")

# %%
sns.set()
fig = pyplot.figure(0, (12, 4))

ax = pyplot.subplot(1, 2, 1)
sns.lineplot(history.epoch, history.history['accuracy'], label='train')
sns.lineplot(history.epoch, history.history['val_accuracy'], label='valid')
pyplot.title('Accuracy')
pyplot.tight_layout()

ax = pyplot.subplot(1, 2, 2)
sns.lineplot(history.epoch, history.history['loss'], label='train')
sns.lineplot(history.epoch, history.history['val_loss'], label='valid')
pyplot.title('Loss')
pyplot.tight_layout()

pyplot.savefig('epoch_history_mobilenet.png')
pyplot.show()
# Out:
# F:\anaconda3\envs\MachineLearning\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# F:\anaconda3\envs\MachineLearning\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# F:\anaconda3\envs\MachineLearning\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# F:\anaconda3\envs\MachineLearning\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
label_to_text
# Out:
# {0: 'happy', 1: 'neutral', 2: 'sad'}

# %%
text_to_label = dict((v,k) for k,v in label_to_text.items())
text_to_label
# Out:
# {'happy': 0, 'neutral': 1, 'sad': 2}

# %%
yhat_test = np.argmax(model.predict(X_test), axis=1)
ytest_ = np.argmax(y_test, axis=1)

scikitplot.metrics.plot_confusion_matrix(ytest_, yhat_test, figsize=(7,7))
pyplot.savefig("confusion_matrix_mobilenet.png")

test_accu = np.sum(ytest_ == yhat_test) / len(ytest_) * 100
print(f"test accuracy: {round(test_accu, 4)} %\n\n")

print(classification_report(ytest_, yhat_test))
# Out:
# test accuracy: 79.7837 %
#
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91       899
#            1       0.68      0.73      0.70       620
#            2       0.73      0.72      0.73       608
#
#     accuracy                           0.80      2127
#    macro avg       0.78      0.78      0.78      2127
# weighted avg       0.80      0.80      0.80      2127

# %%
np.random.seed(42)
sad_imgs = np.random.choice(np.where(y_test[:, text_to_label["sad"]]==1)[0], size=9, replace=False)
happy_imgs = np.random.choice(np.where(y_test[:, text_to_label["happy"]]==1)[0], size=9, replace=False)

fig = pyplot.figure(1, (18, 4))

for i, (sad_idx, happy_idx) in enumerate(zip(sad_imgs, happy_imgs)):
        sample_img = X_test[sad_idx,:,:,:]
        sample_img = sample_img.reshape(1,*sample_img.shape)
        pred = label_to_text[np.argmax(model.predict(sample_img), axis=1)[0]]

        ax = pyplot.subplot(2, 9, i+1)
        ax.imshow(sample_img[0,:,:,0], cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(f"t:sad, p:{pred}")

        sample_img = X_test[happy_idx,:,:,:]
        sample_img = sample_img.reshape(1,*sample_img.shape)
        pred = label_to_text[np.argmax(model.predict(sample_img), axis=1)[0]]

        ax = pyplot.subplot(2, 9, i+10)
        ax.imshow(sample_img[0,:,:,0], cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(f"t:happy, p:{pred}")

        pyplot.tight_layout()
